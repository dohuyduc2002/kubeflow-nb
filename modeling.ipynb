# %%
! pip install -r requirements.txt -q
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/opt/conda/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~umpy (/opt/conda/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~umpy (/opt/conda/lib/python3.11/site-packages)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import mlflow
import mlflow.xgboost
import shap

# %%
import boto3
import io

s3 = boto3.client(
    's3',
    endpoint_url='http://minio-service.kubeflow.svc.cluster.local:9000',
    aws_access_key_id='minio',
    aws_secret_access_key='minio123',
)

# %%
obj_test = s3.get_object(Bucket='sample-data', Key='data/data/application_test.csv')
test_df = pd.read_csv(io.BytesIO(obj_test['Body'].read()))

# %%
obj_train = s3.get_object(Bucket='sample-data', Key='data/data/application_train.csv')
train_df = pd.read_csv(io.BytesIO(obj_train['Body'].read()))

# %%
# Get numerical and categorical columns
numerical_features = train_df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = train_df.select_dtypes(include=['object']).columns.tolist()

# Remove 'SK_ID_CURR' and 'TARGET' from numerical features as they are identifiers/target
if 'SK_ID_CURR' in numerical_features:
    numerical_features.remove('SK_ID_CURR')
if 'TARGET' in numerical_features:
    numerical_features.remove('TARGET')

print("Categorical features:", len(categorical_features))
print(categorical_features)
print("\nNumerical features:", len(numerical_features))
print(numerical_features)
# Out:
# Categorical features: 16
# ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE']
#
# Numerical features: 104
# ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR']

# %%
from src.utils import PreprocessFeatureSelector

# Prepare the data (remove target column for features)
X_train = train_df.drop(columns=["TARGET"])
X_test = test_df.copy()
y_train = train_df["TARGET"].values

data_version = "v1"
save_train_data_path = "data/processed/train"
save_test_data_path = "data/processed/test"

# Create and run the PreprocessFeatureSelector wrapper.
pfs = PreprocessFeatureSelector(X_train, X_test, y_train,
                                categorical_features, numerical_features,
                                data_version=data_version,
                                save_train_data_path=save_train_data_path,
                                save_test_data_path=save_test_data_path)
selected_train, selected_test, selected_features, excluded_features = pfs.run()

print("Final Selected Features:", selected_features)
print("Total Excluded Features:", excluded_features)
# Out:
# 2025-04-15 02:10:33.467 | INFO     | src.utils:run:119 - 🚀 Starting preprocessing and filtering...
# 2025-04-15 02:11:05.937 | INFO     | src.utils:run:123 - ✅ Preprocessing complete.
# 2025-04-15 02:11:05.941 | INFO     | src.utils:run:125 - 🧮 Features before filtering: ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR']
# Filtering Features: 100%|██████████| 120/120 [00:02<00:00, 48.62it/s]
# 2025-04-15 02:11:08.485 | INFO     | src.utils:run:129 - 🧹 Filtering complete.
# 2025-04-15 02:11:08.487 | INFO     | src.utils:run:130 - 📊 IV Values: {'NAME_CONTRACT_TYPE': 0.015038765990569908, 'CODE_GENDER': 0.038601324782494645, 'FLAG_OWN_CAR': 0.0065965517935781814, 'FLAG_OWN_REALTY': 0.0005054517867189232, 'NAME_TYPE_SUITE': 0.0010591586350022194, 'NAME_INCOME_TYPE': 0.05786932470655603, 'NAME_EDUCATION_TYPE': 0.04965360274139638, 'NAME_FAMILY_STATUS': 0.021702402976662365, 'NAME_HOUSING_TYPE': 0.015055190097590775, 'OCCUPATION_TYPE': 0.046069508518714344, 'WEEKDAY_APPR_PROCESS_START': 0.000676688845853548, 'ORGANIZATION_TYPE': 0.07164159540142653, 'FONDKAPREMONT_MODE': 0.0037686654472272574, 'HOUSETYPE_MODE': 0.0, 'WALLSMATERIAL_MODE': 0.0037774706587865472, 'EMERGENCYSTATE_MODE': 0.0, 'CNT_CHILDREN': 0.005493035139154811, 'AMT_INCOME_TOTAL': 0.029939118419913376, 'AMT_CREDIT': 0.4032243964494131, 'AMT_ANNUITY': 1.1204046756101027, 'AMT_GOODS_PRICE': 0.13302987974794367, 'REGION_POPULATION_RELATIVE': 0.07183148089427159, 'DAYS_BIRTH': 1.5681146785084445, 'DAYS_EMPLOYED': 0.6394463689408939, 'DAYS_REGISTRATION': 0.753649615948452, 'DAYS_ID_PUBLISH': 0.3224977602762141, 'OWN_CAR_AGE': 0.02334392217112507, 'FLAG_MOBIL': 0.0, 'FLAG_EMP_PHONE': 0.03290712822093699, 'FLAG_WORK_PHONE': 0.01032857349878151, 'FLAG_CONT_MOBILE': 0.0, 'FLAG_PHONE': 0.007941714785907132, 'FLAG_EMAIL': 4.210277112939151e-05, 'CNT_FAM_MEMBERS': 0.005029872694588584, 'REGION_RATING_CLIENT': 0.048316901854250464, 'REGION_RATING_CLIENT_W_CITY': 0.05120149755009072, 'HOUR_APPR_PROCESS_START': 0.01101635390987279, 'REG_REGION_NOT_LIVE_REGION': 0.0, 'REG_REGION_NOT_WORK_REGION': 0.0006227683430817482, 'LIVE_REGION_NOT_WORK_REGION': 0.0, 'REG_CITY_NOT_LIVE_CITY': 0.02229868907167059, 'REG_CITY_NOT_WORK_CITY': 0.032207243949296756, 'LIVE_CITY_NOT_WORK_CITY': 0.013228377372496516, 'EXT_SOURCE_1': 0.0, 'EXT_SOURCE_2': 5.011854086720846, 'EXT_SOURCE_3': 0.3623533712643655, 'APARTMENTS_AVG': 0.09748490473156779, 'BASEMENTAREA_AVG': 0.19316078417595697, 'YEARS_BEGINEXPLUATATION_AVG': 0.03207895592580236, 'YEARS_BUILD_AVG': 0.019386786744643426, 'COMMONAREA_AVG': 0.08804710716718059, 'ELEVATORS_AVG': 0.030736349305448538, 'ENTRANCES_AVG': 0.023077733916853742, 'FLOORSMAX_AVG': 0.03450303714922642, 'FLOORSMIN_AVG': 0.01939397007603156, 'LANDAREA_AVG': 0.1532989322214806, 'LIVINGAPARTMENTS_AVG': 0.06110177937267408, 'LIVINGAREA_AVG': 0.2883721834831321, 'NONLIVINGAPARTMENTS_AVG': 0.00806703987543863, 'NONLIVINGAREA_AVG': 0.1238102522827408, 'APARTMENTS_MODE': 0.05218254937856211, 'BASEMENTAREA_MODE': 0.20434322653460013, 'YEARS_BEGINEXPLUATATION_MODE': 0.03132997266791167, 'YEARS_BUILD_MODE': 0.01998494830683395, 'COMMONAREA_MODE': 0.08573552479878839, 'ELEVATORS_MODE': 0.024949425863501948, 'ENTRANCES_MODE': 0.017649411900728322, 'FLOORSMAX_MODE': 0.026999055202814412, 'FLOORSMIN_MODE': 0.015526661576441461, 'LANDAREA_MODE': 0.1490086185724385, 'LIVINGAPARTMENTS_MODE': 0.03785611345823722, 'LIVINGAREA_MODE': 0.29092592471097195, 'NONLIVINGAPARTMENTS_MODE': 0.004227595154823592, 'NONLIVINGAREA_MODE': 0.09172657468759969, 'APARTMENTS_MEDI': 0.06289821175097612, 'BASEMENTAREA_MEDI': 0.20009633909638458, 'YEARS_BEGINEXPLUATATION_MEDI': 0.0316700673205728, 'YEARS_BUILD_MEDI': 0.01970580894343717, 'COMMONAREA_MEDI': 0.08959112884267079, 'ELEVATORS_MEDI': 0.02720516024779535, 'ENTRANCES_MEDI': 0.018869501430611686, 'FLOORSMAX_MEDI': 0.028853013423695666, 'FLOORSMIN_MEDI': 0.01670001890800627, 'LANDAREA_MEDI': 0.16145005918053543, 'LIVINGAPARTMENTS_MEDI': 0.04531466756839603, 'LIVINGAREA_MEDI': 0.29899016102669784, 'NONLIVINGAPARTMENTS_MEDI': 0.005280462615439294, 'NONLIVINGAREA_MEDI': 0.12710567965339173, 'TOTALAREA_MODE': 0.2956095333764498, 'OBS_30_CNT_SOCIAL_CIRCLE': 0.0018588571771242489, 'DEF_30_CNT_SOCIAL_CIRCLE': 0.012407887406694393, 'OBS_60_CNT_SOCIAL_CIRCLE': 0.0017333951788489179, 'DEF_60_CNT_SOCIAL_CIRCLE': 0.011308139477428111, 'DAYS_LAST_PHONE_CHANGE': 0.24610424190434738, 'FLAG_DOCUMENT_2': 0.0, 'FLAG_DOCUMENT_3': 0.02857910819255194, ' ...
# 2025-04-15 02:11:08.488 | INFO     | src.utils:run:131 - ❌ Features excluded during filtering: ['NAME_CONTRACT_TYPE', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'CNT_CHILDREN', 'AMT_ANNUITY', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'LIVE_CITY_NOT_WORK_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR']
# 2025-04-15 02:11:08.489 | INFO     | src.utils:run:134 - 🔍 Starting Sequential Feature Selection (SFS)...
# 2025-04-15 02:13:38.685 | INFO     | src.utils:run:145 - ✅ SFS complete.
# 2025-04-15 02:13:38.688 | INFO     | src.utils:run:146 - 🏁 Final selected features: ['CODE_GENDER', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'ORGANIZATION_TYPE', 'AMT_CREDIT', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_3']
# 2025-04-15 02:13:38.689 | INFO     | src.utils:run:147 - 🚫 Features excluded by SFS: ['DAYS_ID_PUBLISH', 'REGION_RATING_CLIENT', 'FLAG_EMP_PHONE', 'REG_CITY_NOT_WORK_CITY', 'REGION_POPULATION_RELATIVE', 'REG_CITY_NOT_LIVE_CITY', 'AMT_GOODS_PRICE', 'AMT_INCOME_TOTAL', 'REGION_RATING_CLIENT_W_CITY']
# 2025-04-15 02:13:42.524 | INFO     | src.utils:run:170 - 💾 Saved processed training data to data/processed/train/processed_train_v1.csv
# 2025-04-15 02:13:42.527 | INFO     | src.utils:run:171 - 💾 Saved processed test data to data/processed/test/processed_test_v1.csv
# Final Selected Features: ['CODE_GENDER', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'ORGANIZATION_TYPE', 'AMT_CREDIT', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_3']
# Total Excluded Features: ['NAME_CONTRACT_TYPE', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE', 'CNT_CHILDREN', 'AMT_ANNUITY', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'LIVE_CITY_NOT_WORK_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'DAYS_ID_PUBLISH', 'REGION_RATING_CLIENT', 'FLAG_EMP_PHONE', 'REG_CITY_NOT_WORK_CITY', 'REGION_POPULATION_RELATIVE', 'REG_CITY_NOT_LIVE_CITY', 'AMT_GOODS_PRICE', 'AMT_INCOME_TOTAL', 'REGION_RATING_CLIENT_W_CITY']

# %%
print("Target value counts:")
print(selected_train['TARGET'].value_counts())
print("\nPercentage distribution:")
print(selected_train['TARGET'].value_counts(normalize=True) * 100)
# Out:
# Target value counts:
# TARGET
# 0    282686
# 1     24825
# Name: count, dtype: int64
#
# Percentage distribution:
# TARGET
# 0    91.927118
# 1     8.072882
# Name: proportion, dtype: float64

# %%
from src.trainer import UnderWritingTrainer

processed_train = "data/processed/train/processed_train_v1.csv"
processed_test = "data/processed/test/processed_test_v1.csv"

trained_model = UnderWritingTrainer.train_model(
    model_name="xgb",
    processed_train=processed_train,
    processed_test=processed_test,
    version="v2",
    experiment_name="XGB",
)
# Out:
# 2025-04-15 02:13:43.329 | INFO     | src.trainer:train_model:198 - Start training underwriting model xgb with version v2
# 2025-04-15 02:13:43.864 | INFO     | src.trainer:train_model:227 - No categorical features provided for schema mapping.
# [I 2025-04-15 02:13:43,896] A new study created in memory with name: no-name-bf6fafde-0c3c-4c13-adf6-d03e3454eb9b
# [0]	validation_0-auc:0.63692
# [1]	validation_0-auc:0.65568
# [2]	validation_0-auc:0.67358
# [3]	validation_0-auc:0.67652
# [4]	validation_0-auc:0.67562
# [5]	validation_0-auc:0.67637
# [6]	validation_0-auc:0.67615
# [7]	validation_0-auc:0.67793
# [8]	validation_0-auc:0.68482
# [9]	validation_0-auc:0.68417
# [10]	validation_0-auc:0.68387
# [11]	validation_0-auc:0.68700
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [12]	validation_0-auc:0.69038
# [13]	validation_0-auc:0.68967
# [14]	validation_0-auc:0.69033
# [15]	validation_0-auc:0.68970
# [16]	validation_0-auc:0.68854
# [17]	validation_0-auc:0.68867
# [18]	validation_0-auc:0.68763
# [19]	validation_0-auc:0.68874
# [20]	validation_0-auc:0.68873
# [21]	validation_0-auc:0.68926
# [22]	validation_0-auc:0.68991
# [23]	validation_0-auc:0.69005
# [24]	validation_0-auc:0.69152
# [25]	validation_0-auc:0.69142
# [26]	validation_0-auc:0.69191
# [27]	validation_0-auc:0.69205
# [28]	validation_0-auc:0.69176
# [29]	validation_0-auc:0.69187
# [30]	validation_0-auc:0.69295
# [31]	validation_0-auc:0.69343
# [32]	validation_0-auc:0.69333
# [33]	validation_0-auc:0.69355
# [34]	validation_0-auc:0.69394
# [35]	validation_0-auc:0.69357
# [36]	validation_0-auc:0.69395
# [37]	validation_0-auc:0.69406
# [38]	validation_0-auc:0.69501
# [39]	validation_0-auc:0.69473
# [40]	validation_0-auc:0.69481
# [41]	validation_0-auc:0.69519
# [42]	validation_0-auc:0.69492
# [43]	validation_0-auc:0.69515
# [44]	validation_0-auc:0.69489
# [45]	validation_0-auc:0.69477
# [46]	validation_0-auc:0.69571
# [47]	validation_0-auc:0.69570
# [48]	validation_0-auc:0.69550
# [49]	validation_0-auc:0.69539
# [50]	validation_0-auc:0.69503
# [51]	validation_0-auc:0.69534
# [52]	validation_0-auc:0.69630
# [53]	validation_0-auc:0.69618
# [54]	validation_0-auc:0.69614
# [55]	validation_0-auc:0.69633
# [56]	validation_0-auc:0.69652
# [57]	validation_0-auc:0.69719
# [58]	validation_0-auc:0.69731
# [59]	validation_0-auc:0.69734
# [60]	validation_0-auc:0.69750
# [61]	validation_0-auc:0.69810
# [62]	validation_0-auc:0.69805
# [63]	validation_0-auc:0.69848
# [64]	validation_0-auc:0.69842
# [65]	validation_0-auc:0.69880
# [66]	validation_0-auc:0.69926
# [67]	validation_0-auc:0.69957
# [68]	validation_0-auc:0.69977
# [69]	validation_0-auc:0.69976
# [70]	validation_0-auc:0.69999
# [71]	validation_0-auc:0.70012
# [72]	validation_0-auc:0.70069
# [73]	validation_0-auc:0.70096
# [74]	validation_0-auc:0.70109
# [75]	validation_0-auc:0.70152
# [76]	validation_0-auc:0.70206
# [77]	validation_0-auc:0.70256
# [78]	validation_0-auc:0.70307
# [79]	validation_0-auc:0.70311
# [80]	validation_0-auc:0.70379
# [81]	validation_0-auc:0.70384
# [82]	validation_0-auc:0.70431
# [83]	validation_0-auc:0.70425
# [84]	validation_0-auc:0.70466
# [85]	validation_0-auc:0.70480
# [86]	validation_0-auc:0.70484
# [87]	validation_0-auc:0.70504
# [88]	validation_0-auc:0.70527
# [89]	validation_0-auc:0.70567
# [90]	validation_0-auc:0.70591
# [91]	validation_0-auc:0.70589
# [92]	validation_0-auc:0.70597
# [93]	validation_0-auc:0.70620
# [94]	validation_0-auc:0.70621
# [95]	validation_0-auc:0.70655
# [96]	validation_0-auc:0.70699
# [97]	validation_0-auc:0.70711
# [98]	validation_0-auc:0.70716
# [99]	validation_0-auc:0.70749
# [100]	validation_0-auc:0.70752
# [101]	validation_0-auc:0.70754
# [102]	validation_0-auc:0.70743
# [103]	validation_0-auc:0.70768
# [104]	validation_0-auc:0.70793
# [105]	validation_0-auc:0.70816
# [106]	validation_0-auc:0.70843
# [107]	validation_0-auc:0.70850
# [I 2025-04-15 02:13:44,799] Trial 0 finished with value: 0.9195323805342829 and parameters: {'max_depth': 2, 'learning_rate': 0.023899944848030215, 'n_estimators': 108, 'subsample': 0.5321515598126965, 'colsample_bytree': 0.8682664878529063}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.63692
# [1]	validation_0-auc:0.66280
# [2]	validation_0-auc:0.66685
# [3]	validation_0-auc:0.66721
# [4]	validation_0-auc:0.66817
# [5]	validation_0-auc:0.66815
# [6]	validation_0-auc:0.67228
# [7]	validation_0-auc:0.67216
# [8]	validation_0-auc:0.67822
# [9]	validation_0-auc:0.67803
# [10]	validation_0-auc:0.67803
# [11]	validation_0-auc:0.68123
# [12]	validation_0-auc:0.68512
# [13]	validation_0-auc:0.68608
# [14]	validation_0-auc:0.68551
# [15]	validation_0-auc:0.68418
# [16]	validation_0-auc:0.68562
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [17]	validation_0-auc:0.68650
# [18]	validation_0-auc:0.68604
# [19]	validation_0-auc:0.68859
# [20]	validation_0-auc:0.68905
# [21]	validation_0-auc:0.68827
# [22]	validation_0-auc:0.68738
# [23]	validation_0-auc:0.68693
# [24]	validation_0-auc:0.68789
# [25]	validation_0-auc:0.68806
# [26]	validation_0-auc:0.68784
# [27]	validation_0-auc:0.68728
# [28]	validation_0-auc:0.68726
# [29]	validation_0-auc:0.68711
# [30]	validation_0-auc:0.68934
# [31]	validation_0-auc:0.68913
# [32]	validation_0-auc:0.68838
# [33]	validation_0-auc:0.68934
# [34]	validation_0-auc:0.68975
# [35]	validation_0-auc:0.68965
# [36]	validation_0-auc:0.68942
# [37]	validation_0-auc:0.68917
# [38]	validation_0-auc:0.68986
# [39]	validation_0-auc:0.68981
# [40]	validation_0-auc:0.68949
# [41]	validation_0-auc:0.68916
# [42]	validation_0-auc:0.68924
# [43]	validation_0-auc:0.68923
# [44]	validation_0-auc:0.68937
# [45]	validation_0-auc:0.68928
# [46]	validation_0-auc:0.69018
# [47]	validation_0-auc:0.68983
# [48]	validation_0-auc:0.68973
# [49]	validation_0-auc:0.68936
# [50]	validation_0-auc:0.68918
# [51]	validation_0-auc:0.68927
# [52]	validation_0-auc:0.69034
# [53]	validation_0-auc:0.69064
# [54]	validation_0-auc:0.69042
# [55]	validation_0-auc:0.69040
# [56]	validation_0-auc:0.69014
# [57]	validation_0-auc:0.69068
# [58]	validation_0-auc:0.69070
# [59]	validation_0-auc:0.69078
# [60]	validation_0-auc:0.69104
# [61]	validation_0-auc:0.69157
# [62]	validation_0-auc:0.69131
# [63]	validation_0-auc:0.69122
# [64]	validation_0-auc:0.69153
# [65]	validation_0-auc:0.69152
# [66]	validation_0-auc:0.69155
# [67]	validation_0-auc:0.69152
# [68]	validation_0-auc:0.69148
# [69]	validation_0-auc:0.69150
# [70]	validation_0-auc:0.69158
# [71]	validation_0-auc:0.69195
# [72]	validation_0-auc:0.69251
# [73]	validation_0-auc:0.69271
# [74]	validation_0-auc:0.69279
# [75]	validation_0-auc:0.69334
# [76]	validation_0-auc:0.69352
# [77]	validation_0-auc:0.69406
# [78]	validation_0-auc:0.69446
# [79]	validation_0-auc:0.69447
# [80]	validation_0-auc:0.69494
# [81]	validation_0-auc:0.69476
# [82]	validation_0-auc:0.69544
# [83]	validation_0-auc:0.69527
# [84]	validation_0-auc:0.69580
# [85]	validation_0-auc:0.69579
# [86]	validation_0-auc:0.69571
# [87]	validation_0-auc:0.69568
# [88]	validation_0-auc:0.69560
# [89]	validation_0-auc:0.69620
# [90]	validation_0-auc:0.69629
# [91]	validation_0-auc:0.69628
# [92]	validation_0-auc:0.69640
# [93]	validation_0-auc:0.69687
# [94]	validation_0-auc:0.69693
# [95]	validation_0-auc:0.69730
# [96]	validation_0-auc:0.69765
# [97]	validation_0-auc:0.69756
# [98]	validation_0-auc:0.69762
# [99]	validation_0-auc:0.69806
# [100]	validation_0-auc:0.69802
# [101]	validation_0-auc:0.69781
# [102]	validation_0-auc:0.69773
# [103]	validation_0-auc:0.69775
# [104]	validation_0-auc:0.69773
# [105]	validation_0-auc:0.69776
# [106]	validation_0-auc:0.69797
# [107]	validation_0-auc:0.69796
# [108]	validation_0-auc:0.69826
# [109]	validation_0-auc:0.69852
# [110]	validation_0-auc:0.69884
# [111]	validation_0-auc:0.69924
# [112]	validation_0-auc:0.69921
# [113]	validation_0-auc:0.69926
# [114]	validation_0-auc:0.69919
# [115]	validation_0-auc:0.69912
# [116]	validation_0-auc:0.69906
# [117]	validation_0-auc:0.69904
# [118]	validation_0-auc:0.69903
# [119]	validation_0-auc:0.69917
# [120]	validation_0-auc:0.69959
# [121]	validation_0-auc:0.69967
# [122]	validation_0-auc:0.69966
# [123]	validation_0-auc:0.70002
# [124]	validation_0-auc:0.70004
# [125]	validation_0-auc:0.70001
# [126]	validation_0-auc:0.70001
# [127]	validation_0-auc:0.70002
# [128]	validation_0-auc:0.70002
# [129]	validation_0-auc:0.69999
# [130]	validation_0-auc:0.69990
# [131]	validation_0-auc:0.69991
# [132]	validation_0-auc:0.69987
# [133]	validation_0-auc:0.70024
# [134]	validation_0-auc:0.70030
# [135]	validation_0-auc:0.70062
# [136]	validation_0-auc:0.70057
# [137]	validation_0-auc:0.70069
# [138]	validation_0-auc:0.70067
# [139]	validation_0-auc:0.70065
# [140]	validation_0-auc:0.70066
# [141]	validation_0-auc:0.70085
# [142]	validation_0-auc:0.70099
# [143]	validation_0-auc:0.70097
# [144]	validation_0-auc:0.70099
# [145]	validation_0-auc:0.70108
# [146]	validation_0-auc:0.70103
# [147]	validation_0-auc:0.70105
# [148]	validation_0-auc:0.70106
# [149]	validation_0-auc:0.70113
# [150]	validation_0-auc:0.70120
# [151]	validation_0-auc:0.70150
# [152]	validation_0-auc:0.70171
# [153]	validation_0-auc:0.70174
# [154]	validation_0-auc:0.70177
# [155]	validation_0-auc:0.70176
# [156]	validation_0-auc:0.70182
# [157]	validation_0-auc:0.70192
# [158]	validation_0-auc:0.70200
# [159]	validation_0-auc:0.70202
# [160]	validation_0-auc:0.70202
# [161]	validation_0-auc:0.70211
# [162]	validation_0-auc:0.70237
# [163]	validation_0-auc:0.70243
# [164]	validation_0-auc:0.70260
# [165]	validation_0-auc:0.70266
# [166]	validation_0-auc:0.70284
# [167]	validation_0-auc:0.70309
# [168]	validation_0-auc:0.70307
# [169]	validation_0-auc:0.70312
# [170]	validation_0-auc:0.70330
# [171]	validation_0-auc:0.70331
# [172]	validation_0-auc:0.70337
# [173]	validation_0-auc:0.70342
# [174]	validation_0-auc:0.70346
# [175]	validation_0-auc:0.70348
# [176]	validation_0-auc:0.70353
# [177]	validation_0-auc:0.70358
# [178]	validation_0-auc:0.70377
# [179]	validation_0-auc:0.70395
# [180]	validation_0-auc:0.70409
# [181]	validation_0-auc:0.70414
# [182]	validation_0-auc:0.70412
# [183]	validation_0-auc:0.70413
# [184]	validation_0-auc:0.70412
# [185]	validation_0-auc:0.70407
# [186]	validation_0-auc:0.70426
# [187]	validation_0-auc:0.70434
# [188]	validation_0-auc:0.70436
# [189]	validation_0-auc:0.70436
# [190]	validation_0-auc:0.70458
# [191]	validation_0-auc:0.70455
# [192]	validation_0-auc:0.70476
# [193]	validation_0-auc:0.70489
# [194]	validation_0-auc:0.70507
# [195]	validation_0-auc:0.70514
# [196]	validation_0-auc:0.70532
# [197]	validation_0-auc:0.70547
# [198]	validation_0-auc:0.70565
# [199]	validation_0-auc:0.70580
# [200]	validation_0-auc:0.70583
# [201]	validation_0-auc:0.70596
# [202]	validation_0-auc:0.70611
# [203]	validation_0-auc:0.70630
# [204]	validation_0-auc:0.70654
# [205]	validation_0-auc:0.70677
# [206]	validation_0-auc:0.70686
# [207]	validation_0-auc:0.70710
# [208]	validation_0-auc:0.70711
# [209]	validation_0-auc:0.70723
# [210]	validation_0-auc:0.70746
# [211]	validation_0-auc:0.70747
# [212]	validation_0-auc:0.70761
# [213]	validation_0-auc:0.70765
# [214]	validation_0-auc:0.70785
# [215]	validation_0-auc:0.70785
# [216]	validation_0-auc:0.70797
# [217]	validation_0-auc:0.70806
# [218]	validation_0-auc:0.70811
# [219]	validation_0-auc:0.70830
# [220]	validation_0-auc:0.70841
# [221]	validation_0-auc:0.70845
# [222]	validation_0-auc:0.70857
# [223]	validation_0-auc:0.70853
# [224]	validation_0-auc:0.70858
# [225]	validation_0-auc:0.70872
# [226]	validation_0-auc:0.70885
# [227]	validation_0-auc:0.70898
# [228]	validation_0-auc:0.70915
# [229]	validation_0-auc:0.70922
# [230]	validation_0-auc:0.70931
# [231]	validation_0-auc:0.70940
# [232]	validation_0-auc:0.70941
# [I 2025-04-15 02:13:46,769] Trial 1 finished with value: 0.9195323805342829 and parameters: {'max_depth': 2, 'learning_rate': 0.011638797475400562, 'n_estimators': 233, 'subsample': 0.8079434824997958, 'colsample_bytree': 0.8489635568404086}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.66315
# [1]	validation_0-auc:0.69195
# [2]	validation_0-auc:0.69729
# [3]	validation_0-auc:0.69944
# [4]	validation_0-auc:0.70013
# [5]	validation_0-auc:0.69985
# [6]	validation_0-auc:0.70138
# [7]	validation_0-auc:0.70145
# [8]	validation_0-auc:0.70507
# [9]	validation_0-auc:0.70437
# [10]	validation_0-auc:0.70399
# [11]	validation_0-auc:0.70396
# [12]	validation_0-auc:0.70405
# [13]	validation_0-auc:0.70378
# [14]	validation_0-auc:0.70365
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [15]	validation_0-auc:0.70353
# [16]	validation_0-auc:0.70373
# [17]	validation_0-auc:0.70365
# [18]	validation_0-auc:0.70397
# [19]	validation_0-auc:0.70378
# [20]	validation_0-auc:0.70412
# [21]	validation_0-auc:0.70396
# [22]	validation_0-auc:0.70390
# [23]	validation_0-auc:0.70384
# [24]	validation_0-auc:0.70459
# [25]	validation_0-auc:0.70455
# [26]	validation_0-auc:0.70439
# [27]	validation_0-auc:0.70448
# [28]	validation_0-auc:0.70439
# [29]	validation_0-auc:0.70441
# [30]	validation_0-auc:0.70496
# [31]	validation_0-auc:0.70486
# [32]	validation_0-auc:0.70471
# [33]	validation_0-auc:0.70435
# [34]	validation_0-auc:0.70457
# [35]	validation_0-auc:0.70460
# [36]	validation_0-auc:0.70452
# [37]	validation_0-auc:0.70429
# [38]	validation_0-auc:0.70433
# [39]	validation_0-auc:0.70437
# [40]	validation_0-auc:0.70429
# [41]	validation_0-auc:0.70419
# [42]	validation_0-auc:0.70423
# [43]	validation_0-auc:0.70419
# [44]	validation_0-auc:0.70408
# [45]	validation_0-auc:0.70404
# [46]	validation_0-auc:0.70466
# [47]	validation_0-auc:0.70475
# [48]	validation_0-auc:0.70485
# [49]	validation_0-auc:0.70483
# [50]	validation_0-auc:0.70494
# [51]	validation_0-auc:0.70493
# [52]	validation_0-auc:0.70483
# [53]	validation_0-auc:0.70489
# [54]	validation_0-auc:0.70498
# [55]	validation_0-auc:0.70491
# [56]	validation_0-auc:0.70484
# [57]	validation_0-auc:0.70491
# [58]	validation_0-auc:0.70486
# [59]	validation_0-auc:0.70476
# [60]	validation_0-auc:0.70470
# [61]	validation_0-auc:0.70482
# [62]	validation_0-auc:0.70468
# [63]	validation_0-auc:0.70471
# [64]	validation_0-auc:0.70467
# [65]	validation_0-auc:0.70456
# [66]	validation_0-auc:0.70457
# [67]	validation_0-auc:0.70455
# [68]	validation_0-auc:0.70452
# [69]	validation_0-auc:0.70448
# [70]	validation_0-auc:0.70438
# [71]	validation_0-auc:0.70432
# [72]	validation_0-auc:0.70465
# [73]	validation_0-auc:0.70458
# [74]	validation_0-auc:0.70465
# [75]	validation_0-auc:0.70462
# [76]	validation_0-auc:0.70454
# [77]	validation_0-auc:0.70481
# [78]	validation_0-auc:0.70479
# [79]	validation_0-auc:0.70479
# [80]	validation_0-auc:0.70485
# [81]	validation_0-auc:0.70487
# [82]	validation_0-auc:0.70488
# [83]	validation_0-auc:0.70486
# [84]	validation_0-auc:0.70509
# [85]	validation_0-auc:0.70516
# [86]	validation_0-auc:0.70512
# [87]	validation_0-auc:0.70509
# [88]	validation_0-auc:0.70513
# [89]	validation_0-auc:0.70536
# [90]	validation_0-auc:0.70525
# [91]	validation_0-auc:0.70534
# [92]	validation_0-auc:0.70525
# [93]	validation_0-auc:0.70552
# [94]	validation_0-auc:0.70549
# [95]	validation_0-auc:0.70568
# [96]	validation_0-auc:0.70583
# [97]	validation_0-auc:0.70578
# [98]	validation_0-auc:0.70582
# [99]	validation_0-auc:0.70609
# [100]	validation_0-auc:0.70607
# [101]	validation_0-auc:0.70604
# [102]	validation_0-auc:0.70598
# [103]	validation_0-auc:0.70593
# [104]	validation_0-auc:0.70588
# [105]	validation_0-auc:0.70588
# [106]	validation_0-auc:0.70580
# [107]	validation_0-auc:0.70575
# [108]	validation_0-auc:0.70602
# [109]	validation_0-auc:0.70626
# [110]	validation_0-auc:0.70622
# [111]	validation_0-auc:0.70619
# [112]	validation_0-auc:0.70618
# [113]	validation_0-auc:0.70616
# [114]	validation_0-auc:0.70616
# [115]	validation_0-auc:0.70609
# [116]	validation_0-auc:0.70618
# [117]	validation_0-auc:0.70628
# [118]	validation_0-auc:0.70624
# [119]	validation_0-auc:0.70619
# [120]	validation_0-auc:0.70614
# [121]	validation_0-auc:0.70612
# [122]	validation_0-auc:0.70612
# [123]	validation_0-auc:0.70636
# [124]	validation_0-auc:0.70642
# [125]	validation_0-auc:0.70648
# [126]	validation_0-auc:0.70644
# [127]	validation_0-auc:0.70638
# [128]	validation_0-auc:0.70640
# [129]	validation_0-auc:0.70637
# [130]	validation_0-auc:0.70639
# [131]	validation_0-auc:0.70637
# [132]	validation_0-auc:0.70634
# [133]	validation_0-auc:0.70636
# [134]	validation_0-auc:0.70634
# [135]	validation_0-auc:0.70653
# [136]	validation_0-auc:0.70653
# [137]	validation_0-auc:0.70650
# [138]	validation_0-auc:0.70644
# [139]	validation_0-auc:0.70635
# [140]	validation_0-auc:0.70635
# [141]	validation_0-auc:0.70630
# [I 2025-04-15 02:13:48,174] Trial 2 finished with value: 0.9195323805342829 and parameters: {'max_depth': 4, 'learning_rate': 0.001148809568183889, 'n_estimators': 142, 'subsample': 0.786208700109454, 'colsample_bytree': 0.9807788256459284}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.67536
# [1]	validation_0-auc:0.68523
# [2]	validation_0-auc:0.70347
# [3]	validation_0-auc:0.71097
# [4]	validation_0-auc:0.71412
# [5]	validation_0-auc:0.71494
# [6]	validation_0-auc:0.71414
# [7]	validation_0-auc:0.71488
# [8]	validation_0-auc:0.71726
# [9]	validation_0-auc:0.71726
# [10]	validation_0-auc:0.71830
# [11]	validation_0-auc:0.71919
# [12]	validation_0-auc:0.71982
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [13]	validation_0-auc:0.71960
# [14]	validation_0-auc:0.71976
# [15]	validation_0-auc:0.72005
# [16]	validation_0-auc:0.71998
# [17]	validation_0-auc:0.72025
# [18]	validation_0-auc:0.72035
# [19]	validation_0-auc:0.72035
# [20]	validation_0-auc:0.72069
# [21]	validation_0-auc:0.72085
# [22]	validation_0-auc:0.72117
# [23]	validation_0-auc:0.72105
# [24]	validation_0-auc:0.72133
# [25]	validation_0-auc:0.72131
# [26]	validation_0-auc:0.72150
# [27]	validation_0-auc:0.72157
# [28]	validation_0-auc:0.72169
# [29]	validation_0-auc:0.72169
# [30]	validation_0-auc:0.72192
# [31]	validation_0-auc:0.72203
# [32]	validation_0-auc:0.72212
# [33]	validation_0-auc:0.72219
# [34]	validation_0-auc:0.72224
# [35]	validation_0-auc:0.72220
# [36]	validation_0-auc:0.72220
# [37]	validation_0-auc:0.72228
# [38]	validation_0-auc:0.72239
# [39]	validation_0-auc:0.72240
# [40]	validation_0-auc:0.72240
# [41]	validation_0-auc:0.72237
# [42]	validation_0-auc:0.72245
# [43]	validation_0-auc:0.72260
# [44]	validation_0-auc:0.72264
# [45]	validation_0-auc:0.72264
# [46]	validation_0-auc:0.72270
# [47]	validation_0-auc:0.72268
# [48]	validation_0-auc:0.72269
# [49]	validation_0-auc:0.72265
# [50]	validation_0-auc:0.72260
# [51]	validation_0-auc:0.72264
# [52]	validation_0-auc:0.72266
# [53]	validation_0-auc:0.72274
# [54]	validation_0-auc:0.72267
# [55]	validation_0-auc:0.72272
# [56]	validation_0-auc:0.72268
# [57]	validation_0-auc:0.72273
# [58]	validation_0-auc:0.72274
# [59]	validation_0-auc:0.72274
# [60]	validation_0-auc:0.72276
# [61]	validation_0-auc:0.72280
# [62]	validation_0-auc:0.72279
# [63]	validation_0-auc:0.72285
# [64]	validation_0-auc:0.72288
# [65]	validation_0-auc:0.72285
# [66]	validation_0-auc:0.72290
# [67]	validation_0-auc:0.72291
# [68]	validation_0-auc:0.72288
# [69]	validation_0-auc:0.72281
# [70]	validation_0-auc:0.72275
# [71]	validation_0-auc:0.72280
# [72]	validation_0-auc:0.72280
# [73]	validation_0-auc:0.72281
# [74]	validation_0-auc:0.72283
# [75]	validation_0-auc:0.72280
# [76]	validation_0-auc:0.72277
# [77]	validation_0-auc:0.72280
# [78]	validation_0-auc:0.72278
# [79]	validation_0-auc:0.72273
# [80]	validation_0-auc:0.72275
# [81]	validation_0-auc:0.72283
# [82]	validation_0-auc:0.72285
# [83]	validation_0-auc:0.72289
# [84]	validation_0-auc:0.72285
# [85]	validation_0-auc:0.72284
# [86]	validation_0-auc:0.72284
# [87]	validation_0-auc:0.72285
# [88]	validation_0-auc:0.72288
# [89]	validation_0-auc:0.72289
# [90]	validation_0-auc:0.72287
# [91]	validation_0-auc:0.72290
# [92]	validation_0-auc:0.72293
# [93]	validation_0-auc:0.72283
# [94]	validation_0-auc:0.72285
# [95]	validation_0-auc:0.72284
# [96]	validation_0-auc:0.72277
# [97]	validation_0-auc:0.72274
# [98]	validation_0-auc:0.72273
# [99]	validation_0-auc:0.72268
# [100]	validation_0-auc:0.72264
# [101]	validation_0-auc:0.72259
# [102]	validation_0-auc:0.72256
# [103]	validation_0-auc:0.72256
# [104]	validation_0-auc:0.72259
# [105]	validation_0-auc:0.72255
# [106]	validation_0-auc:0.72255
# [107]	validation_0-auc:0.72254
# [108]	validation_0-auc:0.72253
# [109]	validation_0-auc:0.72251
# [110]	validation_0-auc:0.72248
# [111]	validation_0-auc:0.72238
# [112]	validation_0-auc:0.72240
# [113]	validation_0-auc:0.72245
# [114]	validation_0-auc:0.72243
# [115]	validation_0-auc:0.72237
# [116]	validation_0-auc:0.72235
# [117]	validation_0-auc:0.72234
# [I 2025-04-15 02:13:49,523] Trial 3 finished with value: 0.9195323805342829 and parameters: {'max_depth': 7, 'learning_rate': 0.06751681945731859, 'n_estimators': 118, 'subsample': 0.5893160336345371, 'colsample_bytree': 0.7182935863006293}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.67723
# [1]	validation_0-auc:0.70206
# [2]	validation_0-auc:0.70779
# [3]	validation_0-auc:0.71102
# [4]	validation_0-auc:0.71127
# [5]	validation_0-auc:0.71216
# [6]	validation_0-auc:0.71214
# [7]	validation_0-auc:0.71257
# [8]	validation_0-auc:0.71437
# [9]	validation_0-auc:0.71431
# [10]	validation_0-auc:0.71432
# [11]	validation_0-auc:0.71392
# [12]	validation_0-auc:0.71380
# [13]	validation_0-auc:0.71370
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [14]	validation_0-auc:0.71355
# [15]	validation_0-auc:0.71359
# [16]	validation_0-auc:0.71424
# [17]	validation_0-auc:0.71412
# [18]	validation_0-auc:0.71414
# [19]	validation_0-auc:0.71401
# [20]	validation_0-auc:0.71440
# [21]	validation_0-auc:0.71420
# [22]	validation_0-auc:0.71410
# [23]	validation_0-auc:0.71393
# [24]	validation_0-auc:0.71448
# [25]	validation_0-auc:0.71448
# [26]	validation_0-auc:0.71437
# [27]	validation_0-auc:0.71442
# [28]	validation_0-auc:0.71428
# [29]	validation_0-auc:0.71433
# [30]	validation_0-auc:0.71477
# [31]	validation_0-auc:0.71481
# [32]	validation_0-auc:0.71467
# [33]	validation_0-auc:0.71463
# [34]	validation_0-auc:0.71483
# [35]	validation_0-auc:0.71504
# [36]	validation_0-auc:0.71489
# [37]	validation_0-auc:0.71506
# [38]	validation_0-auc:0.71495
# [39]	validation_0-auc:0.71484
# [40]	validation_0-auc:0.71490
# [41]	validation_0-auc:0.71490
# [42]	validation_0-auc:0.71493
# [43]	validation_0-auc:0.71486
# [44]	validation_0-auc:0.71498
# [45]	validation_0-auc:0.71490
# [46]	validation_0-auc:0.71523
# [47]	validation_0-auc:0.71529
# [48]	validation_0-auc:0.71541
# [49]	validation_0-auc:0.71554
# [50]	validation_0-auc:0.71554
# [51]	validation_0-auc:0.71551
# [52]	validation_0-auc:0.71546
# [53]	validation_0-auc:0.71548
# [54]	validation_0-auc:0.71549
# [55]	validation_0-auc:0.71543
# [56]	validation_0-auc:0.71534
# [57]	validation_0-auc:0.71530
# [58]	validation_0-auc:0.71542
# [59]	validation_0-auc:0.71530
# [60]	validation_0-auc:0.71530
# [61]	validation_0-auc:0.71525
# [62]	validation_0-auc:0.71520
# [63]	validation_0-auc:0.71516
# [64]	validation_0-auc:0.71512
# [65]	validation_0-auc:0.71504
# [66]	validation_0-auc:0.71499
# [67]	validation_0-auc:0.71502
# [68]	validation_0-auc:0.71500
# [69]	validation_0-auc:0.71495
# [70]	validation_0-auc:0.71493
# [71]	validation_0-auc:0.71494
# [72]	validation_0-auc:0.71515
# [73]	validation_0-auc:0.71515
# [74]	validation_0-auc:0.71525
# [75]	validation_0-auc:0.71522
# [76]	validation_0-auc:0.71519
# [77]	validation_0-auc:0.71535
# [78]	validation_0-auc:0.71536
# [79]	validation_0-auc:0.71546
# [80]	validation_0-auc:0.71548
# [81]	validation_0-auc:0.71552
# [82]	validation_0-auc:0.71547
# [83]	validation_0-auc:0.71560
# [84]	validation_0-auc:0.71573
# [85]	validation_0-auc:0.71570
# [86]	validation_0-auc:0.71565
# [87]	validation_0-auc:0.71565
# [88]	validation_0-auc:0.71563
# [89]	validation_0-auc:0.71576
# [90]	validation_0-auc:0.71574
# [91]	validation_0-auc:0.71574
# [92]	validation_0-auc:0.71570
# [93]	validation_0-auc:0.71581
# [94]	validation_0-auc:0.71582
# [95]	validation_0-auc:0.71593
# [96]	validation_0-auc:0.71602
# [97]	validation_0-auc:0.71602
# [98]	validation_0-auc:0.71597
# [99]	validation_0-auc:0.71606
# [100]	validation_0-auc:0.71604
# [101]	validation_0-auc:0.71602
# [102]	validation_0-auc:0.71599
# [103]	validation_0-auc:0.71604
# [104]	validation_0-auc:0.71604
# [105]	validation_0-auc:0.71600
# [106]	validation_0-auc:0.71602
# [107]	validation_0-auc:0.71600
# [108]	validation_0-auc:0.71610
# [109]	validation_0-auc:0.71619
# [110]	validation_0-auc:0.71619
# [111]	validation_0-auc:0.71623
# [112]	validation_0-auc:0.71628
# [113]	validation_0-auc:0.71630
# [114]	validation_0-auc:0.71633
# [115]	validation_0-auc:0.71631
# [116]	validation_0-auc:0.71636
# [117]	validation_0-auc:0.71640
# [118]	validation_0-auc:0.71645
# [119]	validation_0-auc:0.71643
# [120]	validation_0-auc:0.71641
# [121]	validation_0-auc:0.71645
# [122]	validation_0-auc:0.71647
# [123]	validation_0-auc:0.71653
# [124]	validation_0-auc:0.71652
# [125]	validation_0-auc:0.71655
# [126]	validation_0-auc:0.71652
# [127]	validation_0-auc:0.71652
# [128]	validation_0-auc:0.71656
# [129]	validation_0-auc:0.71657
# [130]	validation_0-auc:0.71658
# [131]	validation_0-auc:0.71657
# [132]	validation_0-auc:0.71656
# [133]	validation_0-auc:0.71661
# [134]	validation_0-auc:0.71662
# [135]	validation_0-auc:0.71670
# [136]	validation_0-auc:0.71676
# [137]	validation_0-auc:0.71674
# [138]	validation_0-auc:0.71672
# [139]	validation_0-auc:0.71670
# [140]	validation_0-auc:0.71671
# [141]	validation_0-auc:0.71669
# [142]	validation_0-auc:0.71667
# [143]	validation_0-auc:0.71666
# [144]	validation_0-auc:0.71666
# [145]	validation_0-auc:0.71668
# [146]	validation_0-auc:0.71668
# [147]	validation_0-auc:0.71670
# [148]	validation_0-auc:0.71669
# [149]	validation_0-auc:0.71667
# [150]	validation_0-auc:0.71666
# [151]	validation_0-auc:0.71671
# [152]	validation_0-auc:0.71671
# [153]	validation_0-auc:0.71674
# [154]	validation_0-auc:0.71672
# [155]	validation_0-auc:0.71673
# [156]	validation_0-auc:0.71672
# [157]	validation_0-auc:0.71671
# [158]	validation_0-auc:0.71671
# [159]	validation_0-auc:0.71669
# [160]	validation_0-auc:0.71672
# [161]	validation_0-auc:0.71670
# [162]	validation_0-auc:0.71677
# [163]	validation_0-auc:0.71681
# [164]	validation_0-auc:0.71680
# [165]	validation_0-auc:0.71681
# [166]	validation_0-auc:0.71682
# [167]	validation_0-auc:0.71688
# [168]	validation_0-auc:0.71687
# [169]	validation_0-auc:0.71686
# [170]	validation_0-auc:0.71690
# [171]	validation_0-auc:0.71690
# [172]	validation_0-auc:0.71689
# [173]	validation_0-auc:0.71689
# [174]	validation_0-auc:0.71685
# [175]	validation_0-auc:0.71684
# [176]	validation_0-auc:0.71680
# [177]	validation_0-auc:0.71684
# [178]	validation_0-auc:0.71689
# [179]	validation_0-auc:0.71697
# [180]	validation_0-auc:0.71702
# [181]	validation_0-auc:0.71702
# [182]	validation_0-auc:0.71701
# [183]	validation_0-auc:0.71705
# [184]	validation_0-auc:0.71705
# [185]	validation_0-auc:0.71706
# [186]	validation_0-auc:0.71706
# [187]	validation_0-auc:0.71706
# [188]	validation_0-auc:0.71709
# [189]	validation_0-auc:0.71707
# [190]	validation_0-auc:0.71705
# [191]	validation_0-auc:0.71707
# [192]	validation_0-auc:0.71710
# [193]	validation_0-auc:0.71709
# [194]	validation_0-auc:0.71707
# [195]	validation_0-auc:0.71706
# [196]	validation_0-auc:0.71704
# [197]	validation_0-auc:0.71706
# [198]	validation_0-auc:0.71712
# [199]	validation_0-auc:0.71717
# [200]	validation_0-auc:0.71716
# [201]	validation_0-auc:0.71715
# [202]	validation_0-auc:0.71719
# [203]	validation_0-auc:0.71717
# [204]	validation_0-auc:0.71722
# [205]	validation_0-auc:0.71720
# [206]	validation_0-auc:0.71724
# [207]	validation_0-auc:0.71722
# [208]	validation_0-auc:0.71721
# [209]	validation_0-auc:0.71722
# [210]	validation_0-auc:0.71723
# [211]	validation_0-auc:0.71723
# [212]	validation_0-auc:0.71725
# [213]	validation_0-auc:0.71724
# [214]	validation_0-auc:0.71725
# [215]	validation_0-auc:0.71725
# [216]	validation_0-auc:0.71725
# [217]	validation_0-auc:0.71723
# [218]	validation_0-auc:0.71723
# [219]	validation_0-auc:0.71720
# [220]	validation_0-auc:0.71722
# [221]	validation_0-auc:0.71720
# [222]	validation_0-auc:0.71719
# [223]	validation_0-auc:0.71719
# [224]	validation_0-auc:0.71719
# [225]	validation_0-auc:0.71723
# [226]	validation_0-auc:0.71721
# [227]	validation_0-auc:0.71725
# [228]	validation_0-auc:0.71723
# [229]	validation_0-auc:0.71726
# [230]	validation_0-auc:0.71727
# [231]	validation_0-auc:0.71727
# [232]	validation_0-auc:0.71730
# [233]	validation_0-auc:0.71730
# [234]	validation_0-auc:0.71734
# [235]	validation_0-auc:0.71732
# [236]	validation_0-auc:0.71730
# [237]	validation_0-auc:0.71730
# [238]	validation_0-auc:0.71729
# [239]	validation_0-auc:0.71730
# [240]	validation_0-auc:0.71732
# [241]	validation_0-auc:0.71731
# [242]	validation_0-auc:0.71730
# [243]	validation_0-auc:0.71729
# [244]	validation_0-auc:0.71733
# [245]	validation_0-auc:0.71731
# [246]	validation_0-auc:0.71735
# [247]	validation_0-auc:0.71733
# [248]	validation_0-auc:0.71736
# [249]	validation_0-auc:0.71738
# [250]	validation_0-auc:0.71739
# [251]	validation_0-auc:0.71739
# [252]	validation_0-auc:0.71737
# [253]	validation_0-auc:0.71737
# [254]	validation_0-auc:0.71738
# [255]	validation_0-auc:0.71739
# [256]	validation_0-auc:0.71739
# [257]	validation_0-auc:0.71740
# [258]	validation_0-auc:0.71740
# [259]	validation_0-auc:0.71740
# [260]	validation_0-auc:0.71739
# [261]	validation_0-auc:0.71739
# [262]	validation_0-auc:0.71740
# [263]	validation_0-auc:0.71739
# [264]	validation_0-auc:0.71738
# [265]	validation_0-auc:0.71739
# [266]	validation_0-auc:0.71739
# [267]	validation_0-auc:0.71741
# [268]	validation_0-auc:0.71743
# [269]	validation_0-auc:0.71742
# [270]	validation_0-auc:0.71742
# [271]	validation_0-auc:0.71742
# [272]	validation_0-auc:0.71745
# [273]	validation_0-auc:0.71746
# [274]	validation_0-auc:0.71747
# [275]	validation_0-auc:0.71752
# [276]	validation_0-auc:0.71754
# [277]	validation_0-auc:0.71756
# [278]	validation_0-auc:0.71756
# [279]	validation_0-auc:0.71756
# [280]	validation_0-auc:0.71756
# [281]	validation_0-auc:0.71757
# [282]	validation_0-auc:0.71761
# [283]	validation_0-auc:0.71759
# [284]	validation_0-auc:0.71758
# [285]	validation_0-auc:0.71757
# [286]	validation_0-auc:0.71756
# [287]	validation_0-auc:0.71756
# [288]	validation_0-auc:0.71758
# [289]	validation_0-auc:0.71757
# [290]	validation_0-auc:0.71759
# [291]	validation_0-auc:0.71760
# [292]	validation_0-auc:0.71761
# [293]	validation_0-auc:0.71762
# [294]	validation_0-auc:0.71763
# [295]	validation_0-auc:0.71763
# [296]	validation_0-auc:0.71767
# [297]	validation_0-auc:0.71766
# [298]	validation_0-auc:0.71768
# [299]	validation_0-auc:0.71769
# [300]	validation_0-auc:0.71770
# [301]	validation_0-auc:0.71770
# [302]	validation_0-auc:0.71771
# [303]	validation_0-auc:0.71772
# [304]	validation_0-auc:0.71773
# [305]	validation_0-auc:0.71777
# [306]	validation_0-auc:0.71777
# [307]	validation_0-auc:0.71777
# [308]	validation_0-auc:0.71777
# [309]	validation_0-auc:0.71781
# [310]	validation_0-auc:0.71779
# [311]	validation_0-auc:0.71779
# [312]	validation_0-auc:0.71779
# [313]	validation_0-auc:0.71780
# [314]	validation_0-auc:0.71780
# [315]	validation_0-auc:0.71779
# [316]	validation_0-auc:0.71777
# [317]	validation_0-auc:0.71778
# [318]	validation_0-auc:0.71778
# [319]	validation_0-auc:0.71778
# [320]	validation_0-auc:0.71779
# [321]	validation_0-auc:0.71780
# [322]	validation_0-auc:0.71781
# [323]	validation_0-auc:0.71780
# [324]	validation_0-auc:0.71779
# [325]	validation_0-auc:0.71779
# [326]	validation_0-auc:0.71782
# [327]	validation_0-auc:0.71782
# [328]	validation_0-auc:0.71781
# [329]	validation_0-auc:0.71779
# [330]	validation_0-auc:0.71780
# [331]	validation_0-auc:0.71778
# [332]	validation_0-auc:0.71778
# [333]	validation_0-auc:0.71778
# [334]	validation_0-auc:0.71778
# [335]	validation_0-auc:0.71777
# [336]	validation_0-auc:0.71779
# [337]	validation_0-auc:0.71779
# [338]	validation_0-auc:0.71780
# [339]	validation_0-auc:0.71779
# [340]	validation_0-auc:0.71779
# [341]	validation_0-auc:0.71780
# [342]	validation_0-auc:0.71779
# [343]	validation_0-auc:0.71779
# [344]	validation_0-auc:0.71780
# [345]	validation_0-auc:0.71780
# [346]	validation_0-auc:0.71780
# [347]	validation_0-auc:0.71778
# [348]	validation_0-auc:0.71780
# [349]	validation_0-auc:0.71779
# [350]	validation_0-auc:0.71782
# [351]	validation_0-auc:0.71783
# [352]	validation_0-auc:0.71783
# [353]	validation_0-auc:0.71783
# [354]	validation_0-auc:0.71783
# [355]	validation_0-auc:0.71786
# [356]	validation_0-auc:0.71785
# [357]	validation_0-auc:0.71784
# [358]	validation_0-auc:0.71786
# [359]	validation_0-auc:0.71789
# [360]	validation_0-auc:0.71788
# [361]	validation_0-auc:0.71790
# [362]	validation_0-auc:0.71792
# [363]	validation_0-auc:0.71792
# [364]	validation_0-auc:0.71791
# [365]	validation_0-auc:0.71794
# [366]	validation_0-auc:0.71793
# [367]	validation_0-auc:0.71795
# [368]	validation_0-auc:0.71797
# [369]	validation_0-auc:0.71796
# [370]	validation_0-auc:0.71795
# [371]	validation_0-auc:0.71796
# [372]	validation_0-auc:0.71797
# [373]	validation_0-auc:0.71799
# [374]	validation_0-auc:0.71798
# [375]	validation_0-auc:0.71797
# [376]	validation_0-auc:0.71798
# [377]	validation_0-auc:0.71798
# [378]	validation_0-auc:0.71800
# [379]	validation_0-auc:0.71802
# [380]	validation_0-auc:0.71802
# [381]	validation_0-auc:0.71804
# [382]	validation_0-auc:0.71806
# [383]	validation_0-auc:0.71807
# [384]	validation_0-auc:0.71808
# [385]	validation_0-auc:0.71808
# [386]	validation_0-auc:0.71808
# [387]	validation_0-auc:0.71809
# [388]	validation_0-auc:0.71808
# [389]	validation_0-auc:0.71809
# [390]	validation_0-auc:0.71812
# [391]	validation_0-auc:0.71812
# [392]	validation_0-auc:0.71813
# [393]	validation_0-auc:0.71816
# [394]	validation_0-auc:0.71816
# [395]	validation_0-auc:0.71816
# [396]	validation_0-auc:0.71817
# [397]	validation_0-auc:0.71817
# [398]	validation_0-auc:0.71816
# [399]	validation_0-auc:0.71818
# [400]	validation_0-auc:0.71818
# [401]	validation_0-auc:0.71820
# [402]	validation_0-auc:0.71822
# [403]	validation_0-auc:0.71823
# [404]	validation_0-auc:0.71822
# [405]	validation_0-auc:0.71824
# [406]	validation_0-auc:0.71825
# [407]	validation_0-auc:0.71825
# [408]	validation_0-auc:0.71826
# [409]	validation_0-auc:0.71828
# [410]	validation_0-auc:0.71830
# [411]	validation_0-auc:0.71832
# [412]	validation_0-auc:0.71832
# [413]	validation_0-auc:0.71833
# [414]	validation_0-auc:0.71832
# [415]	validation_0-auc:0.71832
# [416]	validation_0-auc:0.71832
# [417]	validation_0-auc:0.71832
# [418]	validation_0-auc:0.71833
# [419]	validation_0-auc:0.71833
# [420]	validation_0-auc:0.71833
# [421]	validation_0-auc:0.71834
# [422]	validation_0-auc:0.71833
# [423]	validation_0-auc:0.71835
# [424]	validation_0-auc:0.71836
# [425]	validation_0-auc:0.71836
# [426]	validation_0-auc:0.71837
# [427]	validation_0-auc:0.71837
# [428]	validation_0-auc:0.71837
# [429]	validation_0-auc:0.71839
# [430]	validation_0-auc:0.71839
# [431]	validation_0-auc:0.71840
# [432]	validation_0-auc:0.71839
# [433]	validation_0-auc:0.71841
# [434]	validation_0-auc:0.71841
# [435]	validation_0-auc:0.71840
# [436]	validation_0-auc:0.71842
# [437]	validation_0-auc:0.71842
# [438]	validation_0-auc:0.71841
# [439]	validation_0-auc:0.71842
# [440]	validation_0-auc:0.71842
# [441]	validation_0-auc:0.71841
# [442]	validation_0-auc:0.71842
# [443]	validation_0-auc:0.71842
# [444]	validation_0-auc:0.71842
# [445]	validation_0-auc:0.71842
# [446]	validation_0-auc:0.71844
# [447]	validation_0-auc:0.71844
# [448]	validation_0-auc:0.71845
# [449]	validation_0-auc:0.71845
# [450]	validation_0-auc:0.71845
# [451]	validation_0-auc:0.71846
# [452]	validation_0-auc:0.71846
# [453]	validation_0-auc:0.71847
# [454]	validation_0-auc:0.71847
# [455]	validation_0-auc:0.71847
# [456]	validation_0-auc:0.71848
# [457]	validation_0-auc:0.71847
# [458]	validation_0-auc:0.71848
# [459]	validation_0-auc:0.71849
# [460]	validation_0-auc:0.71848
# [I 2025-04-15 02:13:54,445] Trial 4 finished with value: 0.9195323805342829 and parameters: {'max_depth': 6, 'learning_rate': 0.0017709184352429478, 'n_estimators': 461, 'subsample': 0.7124264039698285, 'colsample_bytree': 0.9837912587898436}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.67370
# [1]	validation_0-auc:0.69961
# [2]	validation_0-auc:0.70317
# [3]	validation_0-auc:0.70498
# [4]	validation_0-auc:0.70514
# [5]	validation_0-auc:0.70516
# [6]	validation_0-auc:0.70464
# [7]	validation_0-auc:0.70489
# [8]	validation_0-auc:0.70815
# [9]	validation_0-auc:0.70796
# [10]	validation_0-auc:0.70835
# [11]	validation_0-auc:0.70843
# [12]	validation_0-auc:0.70895
# [13]	validation_0-auc:0.70947
# [14]	validation_0-auc:0.70946
# [15]	validation_0-auc:0.70959
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [16]	validation_0-auc:0.71041
# [17]	validation_0-auc:0.71041
# [18]	validation_0-auc:0.71074
# [19]	validation_0-auc:0.71057
# [20]	validation_0-auc:0.71079
# [21]	validation_0-auc:0.71080
# [22]	validation_0-auc:0.71081
# [23]	validation_0-auc:0.71094
# [24]	validation_0-auc:0.71175
# [25]	validation_0-auc:0.71194
# [26]	validation_0-auc:0.71228
# [27]	validation_0-auc:0.71243
# [28]	validation_0-auc:0.71248
# [29]	validation_0-auc:0.71272
# [30]	validation_0-auc:0.71319
# [31]	validation_0-auc:0.71331
# [32]	validation_0-auc:0.71333
# [33]	validation_0-auc:0.71356
# [34]	validation_0-auc:0.71387
# [35]	validation_0-auc:0.71395
# [36]	validation_0-auc:0.71389
# [37]	validation_0-auc:0.71405
# [38]	validation_0-auc:0.71422
# [39]	validation_0-auc:0.71420
# [40]	validation_0-auc:0.71444
# [41]	validation_0-auc:0.71460
# [42]	validation_0-auc:0.71464
# [43]	validation_0-auc:0.71478
# [44]	validation_0-auc:0.71491
# [45]	validation_0-auc:0.71490
# [46]	validation_0-auc:0.71532
# [47]	validation_0-auc:0.71557
# [48]	validation_0-auc:0.71565
# [49]	validation_0-auc:0.71583
# [50]	validation_0-auc:0.71584
# [51]	validation_0-auc:0.71585
# [52]	validation_0-auc:0.71603
# [53]	validation_0-auc:0.71604
# [54]	validation_0-auc:0.71611
# [55]	validation_0-auc:0.71619
# [56]	validation_0-auc:0.71628
# [57]	validation_0-auc:0.71642
# [58]	validation_0-auc:0.71657
# [59]	validation_0-auc:0.71668
# [60]	validation_0-auc:0.71674
# [61]	validation_0-auc:0.71679
# [62]	validation_0-auc:0.71690
# [63]	validation_0-auc:0.71709
# [64]	validation_0-auc:0.71722
# [65]	validation_0-auc:0.71736
# [66]	validation_0-auc:0.71741
# [67]	validation_0-auc:0.71756
# [68]	validation_0-auc:0.71775
# [69]	validation_0-auc:0.71779
# [70]	validation_0-auc:0.71790
# [71]	validation_0-auc:0.71809
# [72]	validation_0-auc:0.71830
# [73]	validation_0-auc:0.71840
# [74]	validation_0-auc:0.71852
# [75]	validation_0-auc:0.71858
# [76]	validation_0-auc:0.71870
# [77]	validation_0-auc:0.71888
# [78]	validation_0-auc:0.71904
# [79]	validation_0-auc:0.71906
# [80]	validation_0-auc:0.71917
# [81]	validation_0-auc:0.71922
# [82]	validation_0-auc:0.71924
# [83]	validation_0-auc:0.71930
# [84]	validation_0-auc:0.71941
# [85]	validation_0-auc:0.71941
# [86]	validation_0-auc:0.71948
# [87]	validation_0-auc:0.71954
# [88]	validation_0-auc:0.71965
# [89]	validation_0-auc:0.71978
# [90]	validation_0-auc:0.71980
# [91]	validation_0-auc:0.71984
# [92]	validation_0-auc:0.71988
# [93]	validation_0-auc:0.72000
# [94]	validation_0-auc:0.72010
# [95]	validation_0-auc:0.72020
# [96]	validation_0-auc:0.72033
# [97]	validation_0-auc:0.72036
# [98]	validation_0-auc:0.72041
# [99]	validation_0-auc:0.72049
# [100]	validation_0-auc:0.72047
# [101]	validation_0-auc:0.72052
# [102]	validation_0-auc:0.72053
# [103]	validation_0-auc:0.72058
# [104]	validation_0-auc:0.72062
# [105]	validation_0-auc:0.72064
# [106]	validation_0-auc:0.72066
# [107]	validation_0-auc:0.72070
# [108]	validation_0-auc:0.72079
# [109]	validation_0-auc:0.72086
# [110]	validation_0-auc:0.72088
# [111]	validation_0-auc:0.72091
# [112]	validation_0-auc:0.72097
# [113]	validation_0-auc:0.72100
# [114]	validation_0-auc:0.72102
# [115]	validation_0-auc:0.72107
# [116]	validation_0-auc:0.72111
# [117]	validation_0-auc:0.72116
# [118]	validation_0-auc:0.72120
# [119]	validation_0-auc:0.72121
# [120]	validation_0-auc:0.72126
# [121]	validation_0-auc:0.72129
# [122]	validation_0-auc:0.72133
# [123]	validation_0-auc:0.72135
# [124]	validation_0-auc:0.72138
# [125]	validation_0-auc:0.72141
# [126]	validation_0-auc:0.72143
# [127]	validation_0-auc:0.72145
# [128]	validation_0-auc:0.72147
# [129]	validation_0-auc:0.72150
# [130]	validation_0-auc:0.72155
# [131]	validation_0-auc:0.72156
# [132]	validation_0-auc:0.72157
# [133]	validation_0-auc:0.72159
# [134]	validation_0-auc:0.72162
# [135]	validation_0-auc:0.72163
# [136]	validation_0-auc:0.72165
# [137]	validation_0-auc:0.72165
# [138]	validation_0-auc:0.72169
# [139]	validation_0-auc:0.72169
# [140]	validation_0-auc:0.72171
# [141]	validation_0-auc:0.72175
# [142]	validation_0-auc:0.72174
# [143]	validation_0-auc:0.72177
# [144]	validation_0-auc:0.72181
# [145]	validation_0-auc:0.72181
# [146]	validation_0-auc:0.72182
# [147]	validation_0-auc:0.72185
# [148]	validation_0-auc:0.72188
# [149]	validation_0-auc:0.72189
# [150]	validation_0-auc:0.72190
# [151]	validation_0-auc:0.72193
# [152]	validation_0-auc:0.72195
# [153]	validation_0-auc:0.72198
# [154]	validation_0-auc:0.72200
# [155]	validation_0-auc:0.72202
# [156]	validation_0-auc:0.72201
# [157]	validation_0-auc:0.72202
# [158]	validation_0-auc:0.72202
# [159]	validation_0-auc:0.72204
# [160]	validation_0-auc:0.72206
# [161]	validation_0-auc:0.72206
# [162]	validation_0-auc:0.72208
# [163]	validation_0-auc:0.72209
# [164]	validation_0-auc:0.72209
# [165]	validation_0-auc:0.72209
# [166]	validation_0-auc:0.72209
# [167]	validation_0-auc:0.72213
# [168]	validation_0-auc:0.72214
# [169]	validation_0-auc:0.72214
# [170]	validation_0-auc:0.72215
# [171]	validation_0-auc:0.72217
# [172]	validation_0-auc:0.72218
# [173]	validation_0-auc:0.72219
# [174]	validation_0-auc:0.72220
# [175]	validation_0-auc:0.72222
# [176]	validation_0-auc:0.72223
# [177]	validation_0-auc:0.72226
# [178]	validation_0-auc:0.72226
# [179]	validation_0-auc:0.72228
# [180]	validation_0-auc:0.72231
# [181]	validation_0-auc:0.72230
# [182]	validation_0-auc:0.72231
# [183]	validation_0-auc:0.72233
# [184]	validation_0-auc:0.72230
# [185]	validation_0-auc:0.72231
# [186]	validation_0-auc:0.72232
# [187]	validation_0-auc:0.72232
# [188]	validation_0-auc:0.72233
# [189]	validation_0-auc:0.72234
# [190]	validation_0-auc:0.72236
# [191]	validation_0-auc:0.72237
# [192]	validation_0-auc:0.72236
# [193]	validation_0-auc:0.72237
# [194]	validation_0-auc:0.72237
# [195]	validation_0-auc:0.72237
# [196]	validation_0-auc:0.72238
# [197]	validation_0-auc:0.72239
# [198]	validation_0-auc:0.72241
# [199]	validation_0-auc:0.72241
# [200]	validation_0-auc:0.72242
# [201]	validation_0-auc:0.72243
# [202]	validation_0-auc:0.72244
# [203]	validation_0-auc:0.72243
# [204]	validation_0-auc:0.72245
# [205]	validation_0-auc:0.72244
# [206]	validation_0-auc:0.72244
# [207]	validation_0-auc:0.72245
# [208]	validation_0-auc:0.72246
# [209]	validation_0-auc:0.72248
# [210]	validation_0-auc:0.72247
# [211]	validation_0-auc:0.72247
# [212]	validation_0-auc:0.72247
# [213]	validation_0-auc:0.72248
# [214]	validation_0-auc:0.72247
# [215]	validation_0-auc:0.72248
# [216]	validation_0-auc:0.72249
# [217]	validation_0-auc:0.72250
# [218]	validation_0-auc:0.72250
# [219]	validation_0-auc:0.72248
# [220]	validation_0-auc:0.72248
# [221]	validation_0-auc:0.72249
# [222]	validation_0-auc:0.72249
# [223]	validation_0-auc:0.72250
# [224]	validation_0-auc:0.72252
# [225]	validation_0-auc:0.72253
# [226]	validation_0-auc:0.72255
# [227]	validation_0-auc:0.72255
# [228]	validation_0-auc:0.72256
# [229]	validation_0-auc:0.72257
# [230]	validation_0-auc:0.72256
# [231]	validation_0-auc:0.72256
# [232]	validation_0-auc:0.72257
# [233]	validation_0-auc:0.72257
# [234]	validation_0-auc:0.72259
# [235]	validation_0-auc:0.72258
# [236]	validation_0-auc:0.72257
# [237]	validation_0-auc:0.72258
# [238]	validation_0-auc:0.72258
# [239]	validation_0-auc:0.72259
# [240]	validation_0-auc:0.72259
# [241]	validation_0-auc:0.72259
# [242]	validation_0-auc:0.72259
# [243]	validation_0-auc:0.72259
# [244]	validation_0-auc:0.72261
# [245]	validation_0-auc:0.72262
# [246]	validation_0-auc:0.72261
# [247]	validation_0-auc:0.72261
# [248]	validation_0-auc:0.72261
# [249]	validation_0-auc:0.72260
# [250]	validation_0-auc:0.72261
# [251]	validation_0-auc:0.72262
# [252]	validation_0-auc:0.72262
# [253]	validation_0-auc:0.72262
# [254]	validation_0-auc:0.72262
# [255]	validation_0-auc:0.72263
# [256]	validation_0-auc:0.72263
# [257]	validation_0-auc:0.72263
# [258]	validation_0-auc:0.72265
# [259]	validation_0-auc:0.72265
# [260]	validation_0-auc:0.72266
# [261]	validation_0-auc:0.72264
# [262]	validation_0-auc:0.72262
# [263]	validation_0-auc:0.72263
# [264]	validation_0-auc:0.72263
# [265]	validation_0-auc:0.72264
# [266]	validation_0-auc:0.72265
# [267]	validation_0-auc:0.72266
# [268]	validation_0-auc:0.72267
# [269]	validation_0-auc:0.72267
# [270]	validation_0-auc:0.72268
# [271]	validation_0-auc:0.72268
# [272]	validation_0-auc:0.72268
# [273]	validation_0-auc:0.72268
# [274]	validation_0-auc:0.72269
# [275]	validation_0-auc:0.72269
# [276]	validation_0-auc:0.72269
# [277]	validation_0-auc:0.72269
# [278]	validation_0-auc:0.72268
# [279]	validation_0-auc:0.72270
# [280]	validation_0-auc:0.72270
# [281]	validation_0-auc:0.72270
# [I 2025-04-15 02:13:57,144] Trial 5 finished with value: 0.9195323805342829 and parameters: {'max_depth': 5, 'learning_rate': 0.02577733606458182, 'n_estimators': 282, 'subsample': 0.9334267090229948, 'colsample_bytree': 0.924880361470648}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.67495
# [1]	validation_0-auc:0.70815
# [2]	validation_0-auc:0.71353
# [3]	validation_0-auc:0.71791
# [4]	validation_0-auc:0.71883
# [5]	validation_0-auc:0.71876
# [6]	validation_0-auc:0.71861
# [7]	validation_0-auc:0.71875
# [8]	validation_0-auc:0.71986
# [9]	validation_0-auc:0.71986
# [10]	validation_0-auc:0.72013
# [11]	validation_0-auc:0.72027
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:13:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [12]	validation_0-auc:0.72053
# [13]	validation_0-auc:0.72045
# [14]	validation_0-auc:0.72050
# [15]	validation_0-auc:0.72052
# [16]	validation_0-auc:0.72060
# [17]	validation_0-auc:0.72065
# [18]	validation_0-auc:0.72072
# [19]	validation_0-auc:0.72067
# [20]	validation_0-auc:0.72089
# [21]	validation_0-auc:0.72103
# [22]	validation_0-auc:0.72103
# [23]	validation_0-auc:0.72105
# [24]	validation_0-auc:0.72097
# [25]	validation_0-auc:0.72096
# [26]	validation_0-auc:0.72116
# [27]	validation_0-auc:0.72110
# [28]	validation_0-auc:0.72114
# [29]	validation_0-auc:0.72111
# [30]	validation_0-auc:0.72110
# [31]	validation_0-auc:0.72111
# [32]	validation_0-auc:0.72117
# [33]	validation_0-auc:0.72118
# [34]	validation_0-auc:0.72119
# [35]	validation_0-auc:0.72128
# [36]	validation_0-auc:0.72118
# [37]	validation_0-auc:0.72130
# [38]	validation_0-auc:0.72130
# [39]	validation_0-auc:0.72127
# [40]	validation_0-auc:0.72121
# [41]	validation_0-auc:0.72125
# [42]	validation_0-auc:0.72131
# [43]	validation_0-auc:0.72127
# [44]	validation_0-auc:0.72132
# [45]	validation_0-auc:0.72134
# [46]	validation_0-auc:0.72138
# [47]	validation_0-auc:0.72141
# [48]	validation_0-auc:0.72134
# [49]	validation_0-auc:0.72130
# [50]	validation_0-auc:0.72124
# [51]	validation_0-auc:0.72118
# [52]	validation_0-auc:0.72110
# [53]	validation_0-auc:0.72102
# [54]	validation_0-auc:0.72095
# [55]	validation_0-auc:0.72092
# [56]	validation_0-auc:0.72090
# [57]	validation_0-auc:0.72086
# [58]	validation_0-auc:0.72087
# [59]	validation_0-auc:0.72081
# [60]	validation_0-auc:0.72076
# [61]	validation_0-auc:0.72074
# [62]	validation_0-auc:0.72073
# [63]	validation_0-auc:0.72069
# [64]	validation_0-auc:0.72069
# [65]	validation_0-auc:0.72065
# [66]	validation_0-auc:0.72058
# [67]	validation_0-auc:0.72054
# [68]	validation_0-auc:0.72045
# [69]	validation_0-auc:0.72049
# [70]	validation_0-auc:0.72042
# [71]	validation_0-auc:0.72039
# [72]	validation_0-auc:0.72028
# [73]	validation_0-auc:0.72027
# [74]	validation_0-auc:0.72016
# [75]	validation_0-auc:0.72014
# [76]	validation_0-auc:0.72018
# [77]	validation_0-auc:0.72017
# [78]	validation_0-auc:0.72010
# [79]	validation_0-auc:0.72008
# [80]	validation_0-auc:0.72002
# [81]	validation_0-auc:0.71987
# [82]	validation_0-auc:0.71985
# [83]	validation_0-auc:0.71980
# [84]	validation_0-auc:0.71974
# [85]	validation_0-auc:0.71968
# [86]	validation_0-auc:0.71963
# [87]	validation_0-auc:0.71970
# [88]	validation_0-auc:0.71971
# [89]	validation_0-auc:0.71964
# [90]	validation_0-auc:0.71966
# [91]	validation_0-auc:0.71964
# [92]	validation_0-auc:0.71958
# [93]	validation_0-auc:0.71953
# [94]	validation_0-auc:0.71948
# [95]	validation_0-auc:0.71942
# [96]	validation_0-auc:0.71927
# [97]	validation_0-auc:0.71914
# [98]	validation_0-auc:0.71909
# [99]	validation_0-auc:0.71890
# [100]	validation_0-auc:0.71873
# [101]	validation_0-auc:0.71868
# [102]	validation_0-auc:0.71861
# [103]	validation_0-auc:0.71856
# [104]	validation_0-auc:0.71856
# [105]	validation_0-auc:0.71848
# [106]	validation_0-auc:0.71829
# [107]	validation_0-auc:0.71829
# [108]	validation_0-auc:0.71818
# [109]	validation_0-auc:0.71818
# [110]	validation_0-auc:0.71810
# [111]	validation_0-auc:0.71801
# [112]	validation_0-auc:0.71799
# ...
# [297]	validation_0-auc:0.72081
# [298]	validation_0-auc:0.72075
# [299]	validation_0-auc:0.72073
# [300]	validation_0-auc:0.72070
# [301]	validation_0-auc:0.72068
# [302]	validation_0-auc:0.72067
# [303]	validation_0-auc:0.72068
# [304]	validation_0-auc:0.72069
# [305]	validation_0-auc:0.72067
# [306]	validation_0-auc:0.72065
# [307]	validation_0-auc:0.72064
# [308]	validation_0-auc:0.72065
# [309]	validation_0-auc:0.72060
# [310]	validation_0-auc:0.72056
# [311]	validation_0-auc:0.72054
# [312]	validation_0-auc:0.72055
# [313]	validation_0-auc:0.72054
# [314]	validation_0-auc:0.72052
# [315]	validation_0-auc:0.72049
# [316]	validation_0-auc:0.72046
# [317]	validation_0-auc:0.72045
# [318]	validation_0-auc:0.72045
# [319]	validation_0-auc:0.72042
# [320]	validation_0-auc:0.72039
# [321]	validation_0-auc:0.72037
# [322]	validation_0-auc:0.72036
# [323]	validation_0-auc:0.72034
# [324]	validation_0-auc:0.72033
# [325]	validation_0-auc:0.72029
# [326]	validation_0-auc:0.72026
# [327]	validation_0-auc:0.72027
# [328]	validation_0-auc:0.72028
# [329]	validation_0-auc:0.72025
# [330]	validation_0-auc:0.72024
# [331]	validation_0-auc:0.72025
# [332]	validation_0-auc:0.72025
# [333]	validation_0-auc:0.72023
# [334]	validation_0-auc:0.72018
# [335]	validation_0-auc:0.72018
# [336]	validation_0-auc:0.72015
# [337]	validation_0-auc:0.72016
# [338]	validation_0-auc:0.72013
# [339]	validation_0-auc:0.72011
# [340]	validation_0-auc:0.72009
# [341]	validation_0-auc:0.72009
# [342]	validation_0-auc:0.72009
# [343]	validation_0-auc:0.72007
# [344]	validation_0-auc:0.72008
# [345]	validation_0-auc:0.72005
# [346]	validation_0-auc:0.72005
# [347]	validation_0-auc:0.72001
# [348]	validation_0-auc:0.71998
# [349]	validation_0-auc:0.72000
# [350]	validation_0-auc:0.71996
# [I 2025-04-15 02:14:04,928] Trial 8 finished with value: 0.9194836024258979 and parameters: {'max_depth': 6, 'learning_rate': 0.048001591951286615, 'n_estimators': 351, 'subsample': 0.79648882222405, 'colsample_bytree': 0.9330917986178469}. Best is trial 0 with value: 0.9195323805342829.
# [0]	validation_0-auc:0.60091
# [1]	validation_0-auc:0.61879
# [2]	validation_0-auc:0.69981
# [3]	validation_0-auc:0.70456
# [4]	validation_0-auc:0.70283
# [5]	validation_0-auc:0.71052
# [6]	validation_0-auc:0.70904
# [7]	validation_0-auc:0.71274
# [8]	validation_0-auc:0.71637
# [9]	validation_0-auc:0.71706
# [10]	validation_0-auc:0.71842
# [11]	validation_0-auc:0.71965
# [12]	validation_0-auc:0.71952
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:14:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [13]	validation_0-auc:0.71934
# [14]	validation_0-auc:0.71991
# [15]	validation_0-auc:0.72015
# [16]	validation_0-auc:0.72042
# [17]	validation_0-auc:0.72034
# [18]	validation_0-auc:0.72030
# [19]	validation_0-auc:0.72025
# [20]	validation_0-auc:0.72088
# [21]	validation_0-auc:0.72114
# [22]	validation_0-auc:0.72135
# [23]	validation_0-auc:0.72127
# [24]	validation_0-auc:0.72120
# [25]	validation_0-auc:0.72133
# [26]	validation_0-auc:0.72147
# [27]	validation_0-auc:0.72158
# [28]	validation_0-auc:0.72168
# [29]	validation_0-auc:0.72146
# [30]	validation_0-auc:0.72152
# [31]	validation_0-auc:0.72177
# [32]	validation_0-auc:0.72191
# [33]	validation_0-auc:0.72208
# [34]	validation_0-auc:0.72205
# [35]	validation_0-auc:0.72210
# [36]	validation_0-auc:0.72200
# [37]	validation_0-auc:0.72209
# [38]	validation_0-auc:0.72198
# [39]	validation_0-auc:0.72207
# [40]	validation_0-auc:0.72213
# [41]	validation_0-auc:0.72209
# [42]	validation_0-auc:0.72213
# [43]	validation_0-auc:0.72210
# [44]	validation_0-auc:0.72216
# [45]	validation_0-auc:0.72214
# [46]	validation_0-auc:0.72213
# [47]	validation_0-auc:0.72210
# [48]	validation_0-auc:0.72204
# [49]	validation_0-auc:0.72205
# [50]	validation_0-auc:0.72203
# [51]	validation_0-auc:0.72204
# [52]	validation_0-auc:0.72200
# [53]	validation_0-auc:0.72203
# [54]	validation_0-auc:0.72197
# [55]	validation_0-auc:0.72195
# [56]	validation_0-auc:0.72195
# [57]	validation_0-auc:0.72195
# [58]	validation_0-auc:0.72201
# [59]	validation_0-auc:0.72200
# [60]	validation_0-auc:0.72206
# [61]	validation_0-auc:0.72204
# [62]	validation_0-auc:0.72197
# [63]	validation_0-auc:0.72201
# [64]	validation_0-auc:0.72200
# [65]	validation_0-auc:0.72202
# [66]	validation_0-auc:0.72204
# [67]	validation_0-auc:0.72195
# [68]	validation_0-auc:0.72190
# [69]	validation_0-auc:0.72190
# [70]	validation_0-auc:0.72190
# [71]	validation_0-auc:0.72190
# [72]	validation_0-auc:0.72186
# [73]	validation_0-auc:0.72187
# [74]	validation_0-auc:0.72189
# [75]	validation_0-auc:0.72188
# [76]	validation_0-auc:0.72181
# [77]	validation_0-auc:0.72184
# [78]	validation_0-auc:0.72179
# [79]	validation_0-auc:0.72179
# [80]	validation_0-auc:0.72177
# [81]	validation_0-auc:0.72176
# [82]	validation_0-auc:0.72176
# [83]	validation_0-auc:0.72170
# [84]	validation_0-auc:0.72161
# [85]	validation_0-auc:0.72160
# [86]	validation_0-auc:0.72156
# [87]	validation_0-auc:0.72162
# [88]	validation_0-auc:0.72158
# [89]	validation_0-auc:0.72155
# [90]	validation_0-auc:0.72156
# [91]	validation_0-auc:0.72157
# [92]	validation_0-auc:0.72150
# [93]	validation_0-auc:0.72147
# [94]	validation_0-auc:0.72149
# [95]	validation_0-auc:0.72149
# [96]	validation_0-auc:0.72134
# [97]	validation_0-auc:0.72126
# [98]	validation_0-auc:0.72119
# [99]	validation_0-auc:0.72112
# [100]	validation_0-auc:0.72102
# [101]	validation_0-auc:0.72096
# [102]	validation_0-auc:0.72096
# [103]	validation_0-auc:0.72093
# [104]	validation_0-auc:0.72090
# [105]	validation_0-auc:0.72087
# [106]	validation_0-auc:0.72080
# [107]	validation_0-auc:0.72073
# [108]	validation_0-auc:0.72066
# [109]	validation_0-auc:0.72063
# [110]	validation_0-auc:0.72058
# [111]	validation_0-auc:0.72057
# [112]	validation_0-auc:0.72052
# [113]	validation_0-auc:0.72045
# [114]	validation_0-auc:0.72029
# [115]	validation_0-auc:0.72028
# [116]	validation_0-auc:0.72024
# [117]	validation_0-auc:0.72023
# [118]	validation_0-auc:0.72023
# [119]	validation_0-auc:0.72017
# [120]	validation_0-auc:0.72010
# [121]	validation_0-auc:0.72009
# [122]	validation_0-auc:0.72001
# [123]	validation_0-auc:0.71990
# [124]	validation_0-auc:0.71988
# [125]	validation_0-auc:0.71985
# [126]	validation_0-auc:0.71980
# [127]	validation_0-auc:0.71979
# [128]	validation_0-auc:0.71970
# [129]	validation_0-auc:0.71965
# [130]	validation_0-auc:0.71962
# [131]	validation_0-auc:0.71955
# [132]	validation_0-auc:0.71953
# [133]	validation_0-auc:0.71950
# [134]	validation_0-auc:0.71952
# [135]	validation_0-auc:0.71951
# [136]	validation_0-auc:0.71955
# [137]	validation_0-auc:0.71955
# [138]	validation_0-auc:0.71961
# [139]	validation_0-auc:0.71950
# [140]	validation_0-auc:0.71943
# [141]	validation_0-auc:0.71939
# [142]	validation_0-auc:0.71933
# [143]	validation_0-auc:0.71932
# [144]	validation_0-auc:0.71931
# [145]	validation_0-auc:0.71933
# [146]	validation_0-auc:0.71929
# [147]	validation_0-auc:0.71922
# [148]	validation_0-auc:0.71918
# [149]	validation_0-auc:0.71909
# [150]	validation_0-auc:0.71902
# [151]	validation_0-auc:0.71898
# [152]	validation_0-auc:0.71893
# [153]	validation_0-auc:0.71892
# [154]	validation_0-auc:0.71876
# [155]	validation_0-auc:0.71869
# [156]	validation_0-auc:0.71869
# [157]	validation_0-auc:0.71855
# [158]	validation_0-auc:0.71849
# [159]	validation_0-auc:0.71850
# [160]	validation_0-auc:0.71849
# [161]	validation_0-auc:0.71844
# [162]	validation_0-auc:0.71845
# [163]	validation_0-auc:0.71844
# [164]	validation_0-auc:0.71841
# [165]	validation_0-auc:0.71833
# [166]	validation_0-auc:0.71830
# [167]	validation_0-auc:0.71829
# [168]	validation_0-auc:0.71829
# [169]	validation_0-auc:0.71830
# [170]	validation_0-auc:0.71824
# [171]	validation_0-auc:0.71816
# [172]	validation_0-auc:0.71809
# [173]	validation_0-auc:0.71804
# [174]	validation_0-auc:0.71798
# [175]	validation_0-auc:0.71790
# [176]	validation_0-auc:0.71779
# [177]	validation_0-auc:0.71779
# [178]	validation_0-auc:0.71772
# [179]	validation_0-auc:0.71765
# [180]	validation_0-auc:0.71757
# [181]	validation_0-auc:0.71752
# [182]	validation_0-auc:0.71741
# [183]	validation_0-auc:0.71737
# [184]	validation_0-auc:0.71733
# [185]	validation_0-auc:0.71732
# [186]	validation_0-auc:0.71730
# [187]	validation_0-auc:0.71726
# [188]	validation_0-auc:0.71724
# [189]	validation_0-auc:0.71724
# [190]	validation_0-auc:0.71715
# [191]	validation_0-auc:0.71714
# [192]	validation_0-auc:0.71711
# [193]	validation_0-auc:0.71700
# [194]	validation_0-auc:0.71699
# [195]	validation_0-auc:0.71704
# [196]	validation_0-auc:0.71702
# [197]	validation_0-auc:0.71697
# [198]	validation_0-auc:0.71695
# [199]	validation_0-auc:0.71694
# [200]	validation_0-auc:0.71691
# [201]	validation_0-auc:0.71692
# [202]	validation_0-auc:0.71693
# [203]	validation_0-auc:0.71690
# [204]	validation_0-auc:0.71690
# [205]	validation_0-auc:0.71681
# [206]	validation_0-auc:0.71678
# [207]	validation_0-auc:0.71675
# [208]	validation_0-auc:0.71668
# [209]	validation_0-auc:0.71667
# [210]	validation_0-auc:0.71666
# [211]	validation_0-auc:0.71666
# [212]	validation_0-auc:0.71664
# [213]	validation_0-auc:0.71655
# [214]	validation_0-auc:0.71653
# [215]	validation_0-auc:0.71651
# [216]	validation_0-auc:0.71652
# [217]	validation_0-auc:0.71645
# [218]	validation_0-auc:0.71638
# [219]	validation_0-auc:0.71636
# [220]	validation_0-auc:0.71636
# [221]	validation_0-auc:0.71633
# [222]	validation_0-auc:0.71632
# [223]	validation_0-auc:0.71633
# [224]	validation_0-auc:0.71632
# [225]	validation_0-auc:0.71619
# [226]	validation_0-auc:0.71617
# [227]	validation_0-auc:0.71611
# [228]	validation_0-auc:0.71609
# [229]	validation_0-auc:0.71609
# [230]	validation_0-auc:0.71606
# [231]	validation_0-auc:0.71603
# [232]	validation_0-auc:0.71597
# [233]	validation_0-auc:0.71592
# [234]	validation_0-auc:0.71589
# [235]	validation_0-auc:0.71588
# [236]	validation_0-auc:0.71583
# [237]	validation_0-auc:0.71577
# [238]	validation_0-auc:0.71578
# [239]	validation_0-auc:0.71570
# [240]	validation_0-auc:0.71564
# [241]	validation_0-auc:0.71560
# [242]	validation_0-auc:0.71559
# [243]	validation_0-auc:0.71558
# [244]	validation_0-auc:0.71557
# [245]	validation_0-auc:0.71548
# [246]	validation_0-auc:0.71545
# [247]	validation_0-auc:0.71542
# [248]	validation_0-auc:0.71533
# [249]	validation_0-auc:0.71529
# [250]	validation_0-auc:0.71529
# [251]	validation_0-auc:0.71529
# [252]	validation_0-auc:0.71519
# [253]	validation_0-auc:0.71512
# [254]	validation_0-auc:0.71515
# [255]	validation_0-auc:0.71507
# [256]	validation_0-auc:0.71498
# [257]	validation_0-auc:0.71494
# [258]	validation_0-auc:0.71496
# [259]	validation_0-auc:0.71495
# [260]	validation_0-auc:0.71494
# [261]	validation_0-auc:0.71493
# [262]	validation_0-auc:0.71489
# [263]	validation_0-auc:0.71484
# [264]	validation_0-auc:0.71476
# [265]	validation_0-auc:0.71476
# [266]	validation_0-auc:0.71467
# [267]	validation_0-auc:0.71469
# [268]	validation_0-auc:0.71466
# [269]	validation_0-auc:0.71466
# [270]	validation_0-auc:0.71464
# [271]	validation_0-auc:0.71460
# [272]	validation_0-auc:0.71453
# [273]	validation_0-auc:0.71453
# [274]	validation_0-auc:0.71454
# [275]	validation_0-auc:0.71446
# [276]	validation_0-auc:0.71439
# [277]	validation_0-auc:0.71436
# [278]	validation_0-auc:0.71441
# [279]	validation_0-auc:0.71438
# [280]	validation_0-auc:0.71439
# [281]	validation_0-auc:0.71434
# [282]	validation_0-auc:0.71429
# [283]	validation_0-auc:0.71424
# [284]	validation_0-auc:0.71419
# [285]	validation_0-auc:0.71418
# [286]	validation_0-auc:0.71414
# [287]	validation_0-auc:0.71415
# [288]	validation_0-auc:0.71412
# [289]	validation_0-auc:0.71411
# [290]	validation_0-auc:0.71402
# [291]	validation_0-auc:0.71399
# [292]	validation_0-auc:0.71399
# [293]	validation_0-auc:0.71392
# [294]	validation_0-auc:0.71388
# [295]	validation_0-auc:0.71388
# [296]	validation_0-auc:0.71385
# [297]	validation_0-auc:0.71385
# [298]	validation_0-auc:0.71384
# [299]	validation_0-auc:0.71385
# [300]	validation_0-auc:0.71380
# [301]	validation_0-auc:0.71379
# [302]	validation_0-auc:0.71376
# [303]	validation_0-auc:0.71371
# [304]	validation_0-auc:0.71368
# [305]	validation_0-auc:0.71365
# [306]	validation_0-auc:0.71365
# [307]	validation_0-auc:0.71364
# [308]	validation_0-auc:0.71352
# [309]	validation_0-auc:0.71351
# [310]	validation_0-auc:0.71349
# [311]	validation_0-auc:0.71344
# [312]	validation_0-auc:0.71339
# [313]	validation_0-auc:0.71337
# [314]	validation_0-auc:0.71333
# [315]	validation_0-auc:0.71330
# [316]	validation_0-auc:0.71328
# [317]	validation_0-auc:0.71325
# [318]	validation_0-auc:0.71322
# [319]	validation_0-auc:0.71317
# [320]	validation_0-auc:0.71316
# [321]	validation_0-auc:0.71314
# [322]	validation_0-auc:0.71314
# [323]	validation_0-auc:0.71312
# [324]	validation_0-auc:0.71308
# [325]	validation_0-auc:0.71309
# [326]	validation_0-auc:0.71312
# [327]	validation_0-auc:0.71311
# [328]	validation_0-auc:0.71305
# [329]	validation_0-auc:0.71304
# [330]	validation_0-auc:0.71303
# [331]	validation_0-auc:0.71300
# [332]	validation_0-auc:0.71296
# [333]	validation_0-auc:0.71292
# [334]	validation_0-auc:0.71288
# [335]	validation_0-auc:0.71287
# [336]	validation_0-auc:0.71286
# [337]	validation_0-auc:0.71285
# [338]	validation_0-auc:0.71280
# [339]	validation_0-auc:0.71280
# [340]	validation_0-auc:0.71279
# [341]	validation_0-auc:0.71277
# [342]	validation_0-auc:0.71273
# [343]	validation_0-auc:0.71273
# [344]	validation_0-auc:0.71271
# [345]	validation_0-auc:0.71266
# [346]	validation_0-auc:0.71267
# [347]	validation_0-auc:0.71263
# [348]	validation_0-auc:0.71262
# [349]	validation_0-auc:0.71261
# [350]	validation_0-auc:0.71255
# [351]	validation_0-auc:0.71254
# [352]	validation_0-auc:0.71246
# [353]	validation_0-auc:0.71243
# [354]	validation_0-auc:0.71233
# [355]	validation_0-auc:0.71234
# [356]	validation_0-auc:0.71234
# [357]	validation_0-auc:0.71234
# [358]	validation_0-auc:0.71235
# [359]	validation_0-auc:0.71232
# [360]	validation_0-auc:0.71224
# [361]	validation_0-auc:0.71224
# [362]	validation_0-auc:0.71223
# [363]	validation_0-auc:0.71221
# [364]	validation_0-auc:0.71218
# [365]	validation_0-auc:0.71215
# [I 2025-04-15 02:14:09,114] Trial 9 finished with value: 0.9194836024258979 and parameters: {'max_depth': 8, 'learning_rate': 0.08876788185244802, 'n_estimators': 366, 'subsample': 0.8574498869342663, 'colsample_bytree': 0.540802535225285}. Best is trial 0 with value: 0.9195323805342829.
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:14:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2025-04-15 02:14:09.945 | INFO     | src.trainer:log_model:107 - ROC AUC (roc_auc_score): 0.7105458428607876
# 2025-04-15 02:14:09.946 | INFO     | src.trainer:log_model:108 - ROC AUC (computed with auc & roc_curve): 0.7105458428607876
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [02:14:24] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# Successfully registered model 'v2_XGBoost'.
# 2025/04/15 02:14:27 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: v2_XGBoost, version 1
# Created version '1' of model 'v2_XGBoost'.
# 2025-04-15 02:14:27.136 | INFO     | src.trainer:log_model:146 - Registered model as: v2_XGBoost
# 2025-04-15 02:14:27.139 | INFO     | src.trainer:log_model:167 - Appended registered model info to: src/registered_model.json
# 2025-04-15 02:14:27.164 | INFO     | src.trainer:train_model:239 - Finished training underwriting model xgb with version v2
